# %% [markdown]
# # Importation des modèles et de la base de test

# %%
import pickle
import pandas as pd

log_model = pickle.load(open(r"C:\Users\yanis\01 Projets\01 Python Projects\Projet_Tech_Sprint\03_Modèles\0_Modèles_entrainement/log_model.pkl", 'rb'))
rf_model = pickle.load(open(r"C:\Users\yanis\01 Projets\01 Python Projects\Projet_Tech_Sprint\03_Modèles\0_Modèles_entrainement/rf_model.pkl", 'rb'))
gb_model = pickle.load(open(r"C:\Users\yanis\01 Projets\01 Python Projects\Projet_Tech_Sprint\03_Modèles\0_Modèles_entrainement/gb_model.pkl", 'rb'))
xgb_model = pickle.load(open(r"C:\Users\yanis\01 Projets\01 Python Projects\Projet_Tech_Sprint\03_Modèles\0_Modèles_entrainement/xgb_model.pkl", 'rb'))

X=pd.read_csv(r"C:\Users\yanis\01 Projets\01 Python Projects\Projet_Tech_Sprint\02_Données\0_Données_entrainement\X.csv",index_col=0)
X_train=pd.read_csv(r"C:\Users\yanis\01 Projets\01 Python Projects\Projet_Tech_Sprint\02_Données\0_Données_entrainement\X_train.csv",index_col=0)
X_test=pd.read_csv(r"C:\Users\yanis\01 Projets\01 Python Projects\Projet_Tech_Sprint\02_Données\0_Données_entrainement\X_test.csv",index_col=0)
Y=pd.read_csv(r"C:\Users\yanis\01 Projets\01 Python Projects\Projet_Tech_Sprint\02_Données\0_Données_entrainement\Y.csv",index_col=0)
y_train=pd.read_csv(r"C:\Users\yanis\01 Projets\01 Python Projects\Projet_Tech_Sprint\02_Données\0_Données_entrainement\y_train.csv",index_col=0)
y_test=pd.read_csv(r"C:\Users\yanis\01 Projets\01 Python Projects\Projet_Tech_Sprint\02_Données\0_Données_entrainement\y_test.csv",index_col=0)

# %% [markdown]
# ## Permutation importance

# %%
import eli5
from eli5.sklearn import PermutationImportance

perm = PermutationImportance(log_model, random_state=1).fit(X_test, y_test)
eli5.show_weights(perm, feature_names = X_test.columns.tolist())
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights eli5-feature-importances" style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto;">
#     <thead>
#     <tr style="border: none;">
#         <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;">Weight</th>
#         <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#     </tr>
#     </thead>
#     <tbody>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0250
#
#                     &plusmn; 0.0385
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Duration
#             </td>
# ...

# %% [markdown]
# ## Dependance Plot

# %%
import numpy as np
from matplotlib import pyplot as plt
from pdpbox import pdp, get_dataset, info_plots
feature_names = [i for i in X_test.columns if X_test[i].dtype in [np.int64]]
pdp_duration = pdp.pdp_isolate(model=rf_model, dataset=X_test, model_features=feature_names, feature='Duration')

pdp.pdp_plot(pdp_duration, 'Duration')
plt.show()

# %% [markdown]
# ## Utilisation de la librairie SHAP

# %%
import shap
row_to_show = 5
data_for_prediction = X_test.iloc[row_to_show]  # use 1 row of data here. Could use multiple rows if desired
data_for_prediction_array = data_for_prediction.values.reshape(1, -1)

rf_model.predict_proba(data_for_prediction_array)
# Out:
# array([[0.61, 0.39]])

# %%
explainer  = shap.TreeExplainer(rf_model)
shap_values = explainer.shap_values(data_for_prediction)

# %%
shap.initjs()
shap.force_plot(explainer.expected_value[1], shap_values[1], data_for_prediction)
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,
# ...

# %%
k_explainer = shap.KernelExplainer(rf_model.predict_proba, X_train)
k_shap_values = k_explainer.shap_values(data_for_prediction)
shap.force_plot(k_explainer.expected_value[1], k_shap_values[1], data_for_prediction)
# Out:
# Using 800 background data samples could cause slower run times. Consider using shap.sample(data, K) or shap.kmeans(data, K) to summarize the background as K samples.
# <div id='iWXWDZQU4J0R1K0I4PC33'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
# ...

# %%
k_explainer = shap.KernelExplainer(log_model.predict_proba, X_train)
k_shap_values = k_explainer.shap_values(data_for_prediction)
shap.force_plot(k_explainer.expected_value[1], k_shap_values[1], data_for_prediction)
# Out:
# Using 800 background data samples could cause slower run times. Consider using shap.sample(data, K) or shap.kmeans(data, K) to summarize the background as K samples.
# <div id='iQQNEG0XGN3H7MHRXURMM'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
# ...

# %%
# Create object that can calculate shap values
explainer = shap.TreeExplainer(rf_model)

# calculate shap values. This is what we will plot.
# Calculate shap_values for all of val_X rather than a single row, to have more data for plot.
shap_values = explainer.shap_values(X_test)

# Make plot. Index of [1] is explained in text below.
shap.summary_plot(shap_values[1], X_test)

# %%
# make plot.
shap.dependence_plot('Duration', shap_values[1], X_test, interaction_index="Age")

# %% [markdown]
# ## Elément d'interprétation

# %% [markdown]
# Garder en tete qu'on s'adresse a différent type de professionels, ( agence , concepteur de modèle ...) donc interprété un modèle peu avoir un sens différent selon le métier, les points suivant sont interessant pour lancer la réfléction selon le métier
#
# Why Are These Insights Valuable :
# These insights have many uses, including
#
# Debugging
# Informing feature engineering
# Directing future data collection
# Informing human decision-making
# Building Trust

# %% [markdown]
# permutation importance = stylé , on fait bouger aléatoiremnt les valeurs d'une colonnne et on relance le modèle dessus , la ou le modèle souffre le plus de la permutation de variable => variable imporante

# %% [markdown]
# Info très interessante sur shpa en explicabilité
#
# SHAP Values (an acronym from SHapley Additive exPlanations) break down a prediction to show the impact of each feature. Where could you use this?
#
# A model says a bank shouldn't loan someone money, and the bank is legally required to explain the basis for each loan rejection
